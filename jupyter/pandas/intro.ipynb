# %%
import pandas as pd

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'marley' : ['9172437681', 'Pune'],
              'Bunny' : ['9319284733', 'Nanded'],
              'Rahul' : ['9322857428', 'WesternHills']},
              index=['Number', 'City']
)
# Out:
#             marley       Bunny         Rahul
# Number  9172437681  9319284733    9322857428
# City          Pune      Nanded  WesternHills

# %%
pd.Series([ 'eshil', 'krishna', 'ajay', 'anton' , 'axl' , 'hemanshoe'], name='Gangsters')
# Out:
# 0        eshil
# 1      krishna
# 2         ajay
# 3        anton
# 4          axl
# 5    hemanshoe
# Name: Gangsters, dtype: object

# %%
IMDB = pd.read_csv('SpaceData.csv',na_values=['Unknown'] ,index_col=0)
IMDB.shape
IMDB.head()
# Out:
#                       Name    Type   Distance_LY  Mass_SolarMasses  \
# ObjectID
# 1         Proxima Centauri    Star  4.240000e+00      1.230000e-01
# 2               Betelgeuse    Star  6.425000e+02      1.160000e+01
# 3         Andromeda Galaxy  Galaxy  2.537000e+06      1.500000e+12
# 4              Crab Nebula  Nebula  6.500000e+03               NaN
# 5                  Jupiter  Planet  1.580000e-05      3.178000e+02
#
#             Radius_km  Surface_Temperature_K Discovery_Year  \
# ObjectID
# 1            200000.0                 3042.0           1915
# 2         887600000.0                 3500.0           1836
# 3            220000.0                    NaN            964
# 4                10.0                 6000.0           1054
# 5             69911.0                    NaN            NaN
#
#           Orbital_Period_Days  Number_of_Moons
# ObjectID
# 1                      547.00              0.0
# 2                     2335.00              0.0
# ...

# %%
IMDB.iloc[0]
# Out:
# Name                     Proxima Centauri
# Type                                 Star
# Distance_LY                          4.24
# Mass_SolarMasses                    0.123
# Radius_km                        200000.0
# Surface_Temperature_K                3042
# Discovery_Year                       1915
# Orbital_Period_Days                   547
# Number_of_Moons                         0
# Name: 1, dtype: object

# %%
IMDB.iloc[:, 0]
# Out:
# ObjectID
# 1      Proxima Centauri
# 2            Betelgeuse
# 3      Andromeda Galaxy
# 4           Crab Nebula
# 5               Jupiter
#              ...
# 96              Canopus
# 97               Sirius
# 98           Betelgeuse
# 99            Aldebaran
# 100    Andromeda Galaxy
# Name: Name, Length: 101, dtype: object

# %%
# IMDB.iloc[:3, 0]

IMDB.iloc[-5:]
# Out:
#                       Name    Type  Distance_LY Mass_SolarMasses    Radius_km  \
# ObjectID
# 96                 Canopus    Star        310.0              8.5    7120000.0
# 97                  Sirius    Star          8.6             2.02   11896480.0
# 98              Betelgeuse    Star        642.5             11.6  887600000.0
# 99               Aldebaran    Star         65.1              1.7   61700000.0
# 100       Andromeda Galaxy  Galaxy    2537000.0           1.5e12     220000.0
#
#          Surface_Temperature_K Discovery_Year Orbital_Period_Days  \
# ObjectID
# 96                        7350           2 AD               19.33
# 97                        9940           1844                 365
# 98                        3500           1836                2335
# 99                        3910           1827                 643
# 100                    Unknown            964             Unknown
#
#          Number_of_Moons
# ObjectID
# 96                     0
# ...

# %%
# Access the 'Name' of the row with label 96
IMDB.loc[-10:, 'Radius_km']
# Out:
# ObjectID
# 1         200000.0
# 2      887600000.0
# 3         220000.0
# 4             10.0
# 5          69911.0
#           ...
# 96       7120000.0
# 97      11896480.0
# 98     887600000.0
# 99      61700000.0
# 100       220000.0
# Name: Radius_km, Length: 101, dtype: float64

# %%
IMDB.loc[: , ['Name', 'Type']]
# Out:
#                       Name    Type
# ObjectID
# 1         Proxima Centauri    Star
# 2               Betelgeuse    Star
# 3         Andromeda Galaxy  Galaxy
# 4              Crab Nebula  Nebula
# 5                  Jupiter  Planet
# ...                    ...     ...
# 96                 Canopus    Star
# 97                  Sirius    Star
# 98              Betelgeuse    Star
# 99               Aldebaran    Star
# 100       Andromeda Galaxy  Galaxy
#
# [101 rows x 2 columns]

# %%
IMDB.loc[59:100]
# Out:
#                       Name          Type   Distance_LY Mass_SolarMasses  \
# ObjectID
# 59            Orion Nebula        Nebula  1.344000e+03          Unknown
# 60                   Titan          Moon  1.580000e-05           0.0225
# 61                      Io          Moon  1.580000e-05            0.015
# 62                Callisto          Moon  1.580000e-05            0.018
# 63                  Europa          Moon  1.580000e-05            0.008
# 64               Enceladus          Moon  1.580000e-05         0.000018
# 65                 Neptune        Planet  1.580000e-05             17.1
# 65                 Neptune        Planet  1.580000e-05             17.1
# 66                 Mercury        Planet  1.580000e-05            0.055
# 67                  Uranus        Planet  1.580000e-05            14.54
# 68                  Haumea  Dwarf Planet  1.580000e-05           0.0007
# 69                Makemake  Dwarf Planet  1.580000e-05           0.0007
# ...

# %%
IMDB.loc[:10, ['Name', 'Mass_SolarMasses']]
# Out:
#                       Name Mass_SolarMasses
# ObjectID
# 1         Proxima Centauri            0.123
# 2               Betelgeuse             11.6
# 3         Andromeda Galaxy           1.5e12
# 4              Crab Nebula          Unknown
# 5                  Jupiter            317.8
# 6           Halley's Comet          2.2e-14
# 7                   Sirius             2.02
# 8                     Mars            0.107
# 9                    Venus            0.815
# 10               Milky Way           1.5e12
